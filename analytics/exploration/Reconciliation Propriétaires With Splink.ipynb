# %%
#!pip install splink

# %%
import duckdb
from tqdm.auto import tqdm 
import pandas as pd

connection_source = duckdb.connect(database="../dbt/database_name.duckdb", read_only = True)

# %%
# OK : Filtrer les propriétaires ayant un logements vacant dans la prod (lovac 2024)
# Logement est le lien entre un propriétaire national et départemental 
# Aller chercher les logements via les ID locaux dans les fichiers fonciers
# Aller chercher les logements via les ID locaux dans la prod

# %%
# Queries pour charger les DataFrames
query_owners = """ 
WITH ff_idlocal_idprocte AS (
    SELECT ff_idlocal, ff_idprocpte
    FROM raw_lovac_2024
    UNION ALL
    SELECT ff_idlocal, ff_idprocpte
    FROM raw_lovac_2023
),
ff_idprocte AS (
    SELECT
        ff_idprocpte,
        ff_idlocal
    FROM ff_idlocal_idprocte
),
ff_unique_owner_ids AS (
    SELECT
        o.ff_owner_idpersonne,
        unnest(o.ff_owner_idprocpte) AS idprocpte
    FROM main_int.int_ff_owners_dedup o
),
ff_data AS (
    SELECT oi.ff_owner_idpersonne, oi.idprocpte, ids.ff_idlocal
    FROM ff_unique_owner_ids oi
    LEFT JOIN ff_idprocte ids ON ids.ff_idprocpte = oi.idprocpte
),
prod_owners AS (
    SELECT
        o.id,
        ph.local_id
    FROM main_stg.stg_production_owners o
    JOIN production.ban_addresses ba
        ON ba.address_kind = 'Owner' AND ba.ref_id = o.id
    JOIN main_stg.stg_production_owners_housing poh
        ON poh.owner_id = o.id
    JOIN main_stg.stg_production_housing ph
        ON poh.housing_id = ph.id
    WHERE
        (occupancy_source = 'V' OR occupancy = 'V')
        AND data_file_years IS NOT NULL
        AND list_contains(data_file_years, 'lovac-2024')
        AND o.birth_date IS NOT NULL
        AND idpersonne IS NULL
),
data_to_check AS (
    SELECT prod_owners.id,
            fd.ff_owner_idpersonne,
            array_agg(fd.ff_idlocal) AS local_ids
    FROM prod_owners
    JOIN ff_data fd ON fd.ff_idlocal = prod_owners.local_id
    GROUP BY prod_owners.id, fd.ff_owner_idpersonne
), input_data AS (
SELECT dtc.id, dtc.ff_owner_idpersonne, dtc.local_ids
    , ipo.full_name, ipo.birth_date, ipo.postal_code, ipo.address_dgfip[0]
    , ifo.ff_owner_fullname, ifo.ff_owner_birth_date, ifo.ff_owner_firstname, ifo.ff_owner_lastname, ifo.ff_owner_postal_code
    , ifo.ff_owner_address_1 || ' ' || ifo.ff_owner_address_2 || ' ' || ifo.ff_owner_address_3 || ' ' || ifo.ff_owner_address_4 AS owner_address,

FROM data_to_check dtc
JOIN main_int.int_production_owners ipo ON ipo.id = dtc.id
JOIN main_int.int_ff_owners_dedup ifo ON ifo.ff_owner_idpersonne = dtc.ff_owner_idpersonne)
SELECT *
FROM input_data
"""


df_ff_owners = connection_source.execute(query_owners).fetchdf()
print(df_ff_owners.shape)

connection_source.close()
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# (2284662, 14)

# %%
import uuid

# %%
df_ff_owners["matching_id"] = df_ff_owners["id"].apply(lambda x: str(uuid.uuid4()))

# %%
df_ff_owners.columns
# Out:
# Index(['id', 'ff_owner_idpersonne', 'local_ids', 'full_name', 'birth_date',
#        'postal_code', 'postal_code_1', 'ipo.address_dgfip[0]',
#        'ff_owner_fullname', 'ff_owner_birth_date', 'ff_owner_firstname',
#        'ff_owner_lastname', 'ff_owner_postal_code', 'owner_address',
#        'matching_id'],
#       dtype='object')

# %%
df_prod = df_ff_owners[["id", "matching_id", "full_name", "birth_date", "postal_code", "ipo.address_dgfip[0]"]].rename(
    columns = {
        "id": "unique_id",
        "full_name": "owner_fullname",
        "birth_date": "owner_birth_date",
        "postal_code": "owner_postal_code",
        "ipo.address_dgfip[0]": "owner_address"
    }
)
df_prod["owner_firstname"] = df_prod["owner_fullname"]
df_prod["owner_lastname"] = df_prod["owner_fullname"]

df_ff = df_ff_owners[["ff_owner_idpersonne","matching_id", "ff_owner_fullname", "ff_owner_lastname", "ff_owner_birth_date", "owner_address", "ff_owner_postal_code", "ff_owner_firstname"]].rename(
    columns={
        "ff_owner_idpersonne": "unique_id",
        "ff_owner_fullname": "owner_fullname",
        "ff_owner_lastname": "owner_lastname",
        "ff_owner_birth_date": "owner_birth_date",
        "owner_address": "owner_address",
        "ff_owner_postal_code": "owner_postal_code",
        "ff_owner_firstname": "owner_firstname"
    }
)

# %%
df_ff.shape
# Out:
# (2284662, 8)

# %%
df_ff.unique_id.unique().shape
# Out:
# (1056790,)

# %%
import splink.comparison_library as cl

first_name_comparison = cl.ExactMatch("first_name")

# %%
first_name_comparison.get_comparison("duckdb").as_dict()
# Out:
# {'output_column_name': 'first_name',
#  'comparison_levels': [{'sql_condition': '"first_name_l" IS NULL OR "first_name_r" IS NULL',
#    'label_for_charts': 'first_name is NULL',
#    'is_null_level': True},
#   {'sql_condition': '"first_name_l" = "first_name_r"',
#    'label_for_charts': 'Exact match on first_name'},
#   {'sql_condition': 'ELSE', 'label_for_charts': 'All other comparisons'}],
#  'comparison_description': 'ExactMatch'}

# %%
settings.get_settings("duckdb").as_dict()
# Out:
# {'link_type': 'link_only',
#  'probability_two_random_records_match': 0.0001,
#  'retain_matching_columns': True,
#  'retain_intermediate_calculation_columns': False,
#  'additional_columns_to_retain': [],
#  'sql_dialect': 'duckdb',
#  'linker_uid': 'fy6xvrlq',
#  'em_convergence': 0.0001,
#  'max_iterations': 25,
#  'bayes_factor_column_prefix': 'bf_',
#  'term_frequency_adjustment_column_prefix': 'tf_',
#  'comparison_vector_value_column_prefix': 'gamma_',
#  'unique_id_column_name': 'unique_id',
#  'source_dataset_column_name': 'source_dataset',
#  'blocking_rules_to_generate_predictions': [{'blocking_rule': 'l."matching_id" = r."matching_id"',
#    'sql_dialect': 'duckdb'}],
#  'comparisons': [{'output_column_name': 'owner_fullname',
#    'comparison_levels': [{'sql_condition': '"owner_fullname_l" IS NULL OR "owner_fullname_r" IS NULL',
#      'label_for_charts': 'owner_fullname is NULL',
#      'is_null_level': True},
#     {'sql_condition': '"owner_fullname_l" = "owner_fullname_r"',
#      'label_for_charts': 'Exact match on owner_fullname',
#      'tf_adjustment_column': 'owner_fullname',
#      'tf_adjustment_weight': 1.0},
#     {'sql_condition': 'jaro_winkler_similarity("owner_fullname_l", "owner_fullname_r") >= 0.92',
#      'label_for_charts': 'Jaro-Winkler distance of owner_fullname >= 0.92'},
#     {'sql_condition': 'jaro_winkler_similarity("owner_fullname_l", "owner_fullname_r") >= 0.88',
#      'label_for_charts': 'Jaro-Winkler distance of owner_fullname >= 0.88'},
#     {'sql_condition': 'jaro_winkler_similarity("owner_fullname_l", "owner_fullname_r") >= 0.7',
#      'label_for_charts': 'Jaro-Winkler distance of owner_fullname >= 0.7'},
#     {'sql_condition': 'ELSE', 'label_for_charts': 'All other comparisons'}],
#    'comparison_description': 'NameComparison'},
#   {'output_column_name': 'owner_birth_date',
#    'comparison_levels': [{'sql_condition': '"owner_birth_date_l" IS NULL OR "owner_birth_date_r" IS NULL',
#      'label_for_charts': 'owner_birth_date is NULL',
#      'is_null_level': True},
#     {'sql_condition': '"owner_birth_date_l" = "owner_birth_date_r"',
#      'label_for_charts': 'Exact match on date of birth'},
#     {'sql_condition': 'damerau_levenshtein(CAST("owner_birth_date_l" AS TEXT), CAST("owner_birth_date_r" AS TEXT)) <= 1',
#      'label_for_charts': 'DamerauLevenshtein distance <= 1'},
#     {'sql_condition': 'ABS(EPOCH("owner_birth_date_l") - EPOCH("owner_birth_date_r")) <= 2629800.0',
#      'label_for_charts': 'Abs date difference <= 1 month'},
#     {'sql_condition': 'ABS(EPOCH("owner_birth_date_l") - EPOCH("owner_birth_date_r")) <= 31557600.0',
#      'label_for_charts': 'Abs date difference <= 1 year'},
#     {'sql_condition': 'ABS(EPOCH("owner_birth_date_l") - EPOCH("owner_birth_date_r")) <= 315576000.0',
#      'label_for_charts': 'Abs date difference <= 10 year'},
#     {'sql_condition': 'ELSE', 'label_for_charts': 'All other comparisons'}],
#    'comparison_description': 'DateOfBirthComparison'},
#   {'output_column_name': 'owner_postal_code',
#    'comparison_levels': [{'sql_condition': '"owner_postal_code_l" IS NULL OR "owner_postal_code_r" IS NULL',
#      'label_for_charts': 'owner_postal_code is NULL',
#      'is_null_level': True},
#     {'sql_condition': '"owner_postal_code_l" = "owner_postal_code_r"',
#      'label_for_charts': 'Exact match on full postcode'},
#     {'sql_condition': 'NULLIF(regexp_extract("owner_postal_code_l", \'^[A-Za-z]{1,2}[0-9][A-Za-z0-9]? [0-9]\', 0), \'\') = NULLIF(regexp_extract("owner_postal_code_r", \'^[A-Za-z]{1,2}[0-9][A-Za-z0-9]? [0-9]\', 0), \'\')',
#      'label_for_charts': 'Exact match on sector'},
#     {'sql_condition': 'NULLIF(regexp_extract("owner_postal_code_l", \'^[A-Za-z]{1,2}[0-9][A-Za-z0-9]?\', 0), \'\') = NULLIF(regexp_extract("owner_postal_code_r", \'^[A-Za-z]{1,2}[0-9][A-Za-z0-9]?\', 0), \'\')',
#      'label_for_charts': 'Exact match on district'},
#     {'sql_condition': 'NULLIF(regexp_extract("owner_postal_code_l", \'^[A-Za-z]{1,2}\', 0), \'\') = NULLIF(regexp_extract("owner_postal_code_r", \'^[A-Za-z]{1,2}\', 0), \'\')',
#      'label_for_charts': 'Exact match on area'},
#     {'sql_condition': 'ELSE', 'label_for_charts': 'All other comparisons'}],
#    'comparison_description': 'PostcodeComparison'},
#   {'output_column_name': 'owner_address',
#    'comparison_levels': [{'sql_condition': '"owner_address_l" IS NULL OR "owner_address_r" IS NULL',
#      'label_for_charts': 'owner_address is NULL',
#      'is_null_level': True},
#     {'sql_condition': '"owner_address_l" = "owner_address_r"',
#      'label_for_charts': 'Exact match on owner_address'},
#     {'sql_condition': 'jaro_winkler_similarity("owner_address_l", "owner_address_r") >= 0.9',
#      'label_for_charts': 'Jaro-Winkler distance of owner_address >= 0.9'},
#     {'sql_condition': 'jaro_winkler_similarity("owner_address_l", "owner_address_r") >= 0.7',
#      'label_for_charts': 'Jaro-Winkler distance of owner_address >= 0.7'},
#     {'sql_condition': 'ELSE', 'label_for_charts': 'All other comparisons'}],
#    'comparison_description': 'JaroWinklerAtThresholds'},
#   {'output_column_name': 'owner_firstname',
#    'comparison_levels': [{'sql_condition': '"owner_firstname_l" IS NULL OR "owner_firstname_r" IS NULL',
#      'label_for_charts': 'owner_firstname is NULL',
#      'is_null_level': True},
#     {'sql_condition': '"owner_firstname_l" = "owner_firstname_r"',
#      'label_for_charts': 'Exact match on owner_firstname',
#      'tf_adjustment_column': 'owner_firstname',
#      'tf_adjustment_weight': 1.0},
#     {'sql_condition': 'jaro_winkler_similarity("owner_firstname_l", "owner_firstname_r") >= 0.92',
#      'label_for_charts': 'Jaro-Winkler distance of owner_firstname >= 0.92'},
#     {'sql_condition': 'jaro_winkler_similarity("owner_firstname_l", "owner_firstname_r") >= 0.88',
#      'label_for_charts': 'Jaro-Winkler distance of owner_firstname >= 0.88'},
#     {'sql_condition': 'jaro_winkler_similarity("owner_firstname_l", "owner_firstname_r") >= 0.7',
#      'label_for_charts': 'Jaro-Winkler distance of owner_firstname >= 0.7'},
#     {'sql_condition': 'ELSE', 'label_for_charts': 'All other comparisons'}],
#    'comparison_description': 'NameComparison'},
#   {'output_column_name': 'owner_lastname',
#    'comparison_levels': [{'sql_condition': '"owner_lastname_l" IS NULL OR "owner_lastname_r" IS NULL',
#      'label_for_charts': 'owner_lastname is NULL',
#      'is_null_level': True},
#     {'sql_condition': '"owner_lastname_l" = "owner_lastname_r"',
#      'label_for_charts': 'Exact match on owner_lastname',
#      'tf_adjustment_column': 'owner_lastname',
#      'tf_adjustment_weight': 1.0},
#     {'sql_condition': 'jaro_winkler_similarity("owner_lastname_l", "owner_lastname_r") >= 0.92',
#      'label_for_charts': 'Jaro-Winkler distance of owner_lastname >= 0.92'},
#     {'sql_condition': 'jaro_winkler_similarity("owner_lastname_l", "owner_lastname_r") >= 0.88',
#      'label_for_charts': 'Jaro-Winkler distance of owner_lastname >= 0.88'},
#     {'sql_condition': 'jaro_winkler_similarity("owner_lastname_l", "owner_lastname_r") >= 0.7',
#      'label_for_charts': 'Jaro-Winkler distance of owner_lastname >= 0.7'},
#     {'sql_condition': 'ELSE', 'label_for_charts': 'All other comparisons'}],
#    'comparison_description': 'NameComparison'}]}

# %%
import splink.comparison_library as cl
from splink import DuckDBAPI, Linker, SettingsCreator, block_on

settings = SettingsCreator(
    link_type="link_only",
    blocking_rules_to_generate_predictions=[
        block_on("matching_id"),
    ],
    comparisons=[
        cl.NameComparison(
            "owner_fullname",
        ),
        cl.DateOfBirthComparison(
            "owner_birth_date",
            invalid_dates_as_null=True,
            input_is_string=False
        ),
        cl.PostcodeComparison(
            "owner_postal_code",
        ),
        cl.JaroWinklerAtThresholds(
            "owner_address",
        ),
        cl.NameComparison(
            "owner_firstname",
        ),
        cl.NameComparison(
            "owner_lastname",
        ),
    ],
)

linker = Linker(
    [df_prod, df_ff],
    settings,
    db_api=DuckDBAPI(),
    input_table_aliases=["df_prod", "df_ff"],
)

# %%
linker.training.estimate_probability_two_random_records_match(
    [block_on("matching_id")],
    recall=0.7,
)
# Out:
# Probability two random records match is estimated to be  6.25e-07.
# This means that amongst all possible pairwise record comparisons, one in 1,599,263.40 are expected to match.  With 5,219,680,454,244 total possible comparisons, we expect a total of around 3,263,802.86 matching pairs

# %%
linker.training.estimate_parameters_using_expectation_maximisation(
    block_on("matching_id")
)
# Out:
# ---------------------------------------------------------------------------
# ConversionException                       Traceback (most recent call last)
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/splink/internals/database_api.py:63, in DatabaseAPI._log_and_run_sql_execution(self, final_sql, templated_name, physical_name)
#      62 try:
# ---> 63     return self._execute_sql_against_backend(final_sql)
#      64 except Exception as e:
#      65     # Parse our SQL through sqlglot to pretty print
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/splink/internals/duckdb/database_api.py:104, in DuckDBAPI._execute_sql_against_backend(self, final_sql)
#     103 def _execute_sql_against_backend(self, final_sql: str) -> duckdb.DuckDBPyRelation:
# --> 104     return self._con.sql(final_sql)
#
# ConversionException: Conversion Error: Could not convert string '29PBF3HD' to INT128
# LINE 13:             "unique_id", "matching_id", "owner_fullname", "owner_birth_date", "owner_postal_code", "owner_address", "owner_firstname", "owner_lastname"
#             , random() as __splink_salt
#             from df_ff
#             ),
#
# __splink__df_tf_owner_fullname as (
#     select
#     "owner_fullname", cast(count(*) as float8) / (select
#         count("owner_fullname") as total from __splink__df_concat)
#             as "tf_owner_fullname"
#     from __splink__df_concat
#     where "owner_fullname" is not null
#     group by "owner_fullname"
#     ),
#
# __splink__df_tf_owner_lastname as (
#     select
#     "owner_lastname", cast(count(*) as float8) / (select
#         count("owner_lastname") as total from __splink__df_concat)
#             as "tf_owner_lastname"
#     from __splink__df_concat
#     where "owner_lastname" is not null
#     group by "owner_lastname"
#     ),
#
# __splink__df_tf_owner_firstname as (
#     select
#     "owner_firstname", cast(count(*) as float8) / (select
#         count("owner_firstname") as total from __splink__df_concat)
#             as "tf_owner_firstname"
#     from __splink__df_concat
#     where "owner_firstname" is not null
#     group by "owner_firstname"
#     )
#
#     select __splink__df_concat.*, __splink__df_tf_owner_fullname."tf_owner_fullname", __splink__df_tf_owner_lastname."tf_owner_lastname", __splink__df_tf_owner_firstname."tf_owner_firstname"
#     from __splink__df_concat
#     left join __splink__df_tf_owner_fullname on __splink__df_concat."owner_fullname" = __splink__df_tf_owner_fullname."owner_fullname" left join __splink__df_tf_owner_lastname on __splink__df_concat."owner_lastname" = __splink__df_tf_owner_lastname."owner_lastname" left join __splink__df_tf_owner_firstname on __splink__df_concat."owner_firstname" = __splink__df_tf_owner_firstname."owner_firstname"
#     ...
#                      ^
#
# The above exception was the direct cause of the following exception:
#
# SplinkException                           Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 linker.training.estimate_parameters_using_expectation_maximisation(
#       2     block_on("matching_id")
#       3 )
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/splink/internals/linker_components/training.py:286, in LinkerTraining.estimate_parameters_using_expectation_maximisation(self, blocking_rule, estimate_without_term_frequencies, fix_probability_two_random_records_match, fix_m_probabilities, fix_u_probabilities, populate_probability_two_random_records_match_from_trained_values)
#     283 # Ensure this has been run on the main linker so that it's in the cache
#     284 # to be used by the training linkers
#     285 pipeline = CTEPipeline()
# --> 286 compute_df_concat_with_tf(self._linker, pipeline)
#     288 blocking_rule_obj = to_blocking_rule_creator(blocking_rule).get_blocking_rule(
#     289     self._linker._sql_dialect_str
#     290 )
#     292 if not isinstance(blocking_rule_obj, (BlockingRule, SaltedBlockingRule)):
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/splink/internals/vertically_concatenate.py:126, in compute_df_concat_with_tf(linker, pipeline)
#     123 sqls = compute_all_term_frequencies_sqls(linker, pipeline)
#     124 pipeline.enqueue_list_of_sqls(sqls)
# --> 126 nodes_with_tf = db_api.sql_pipeline_to_splink_dataframe(pipeline)
#     127 cache["__splink__df_concat_with_tf"] = nodes_with_tf
#     128 return nodes_with_tf
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/splink/internals/database_api.py:200, in DatabaseAPI.sql_pipeline_to_splink_dataframe(self, pipeline, use_cache)
#     197     sql_gen = pipeline.generate_cte_pipeline_sql()
#     198     output_tablename_templated = pipeline.output_table_name
# --> 200     splink_dataframe = self.sql_to_splink_dataframe_checking_cache(
#     201         sql_gen,
#     202         output_tablename_templated,
#     203         use_cache,
#     204     )
#     205 else:
#     206     # In debug mode, we do not pipeline the sql and print the
#     207     # results of each part of the pipeline
#     208     for cte in pipeline.ctes_pipeline():
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/splink/internals/database_api.py:171, in DatabaseAPI.sql_to_splink_dataframe_checking_cache(self, sql, output_tablename_templated, use_cache)
#     168         print(df_pd)  # noqa: T201
#     170 else:
# --> 171     splink_dataframe = self._sql_to_splink_dataframe(
#     172         sql, output_tablename_templated, table_name_hash
#     173     )
#     175 splink_dataframe.created_by_splink = True
#     176 splink_dataframe.sql_used_to_create = sql
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/splink/internals/database_api.py:93, in DatabaseAPI._sql_to_splink_dataframe(self, sql, templated_name, physical_name)
#      85 """
#      86 Create a table in the backend using some given sql
#      87
#    (...)
#      90 Returns a SplinkDataFrame which also uses templated_name
#      91 """
#      92 sql = self._setup_for_execute_sql(sql, physical_name)
# ---> 93 spark_df = self._log_and_run_sql_execution(sql, templated_name, physical_name)
#      94 output_df = self._cleanup_for_execute_sql(
#      95     spark_df, templated_name, physical_name
#      96 )
#      97 self._intermediate_table_cache.executed_queries.append(output_df)
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/splink/internals/database_api.py:75, in DatabaseAPI._log_and_run_sql_execution(self, final_sql, templated_name, physical_name)
#      72 except Exception:
#      73     pass
# ---> 75 raise SplinkException(
#      76     f"Error executing the following sql for table "
#      77     f"`{templated_name}`({physical_name}):\n{final_sql}"
#      78     f"\n\nError was: {e}"
#      79 ) from e
#
# SplinkException: Error executing the following sql for table `__splink__df_concat_with_tf`(__splink__df_concat_with_tf_a2481cf80):
# CREATE TABLE __splink__df_concat_with_tf_a2481cf80 AS
# WITH __splink__df_concat AS (
#   SELECT
#     'df_prod' AS source_dataset,
#     "unique_id",
#     "matching_id",
#     "owner_fullname",
#     "owner_birth_date",
#     "owner_postal_code",
#     "owner_address",
#     "owner_firstname",
#     "owner_lastname",
#     RAND() AS __splink_salt
#   FROM df_prod
#   UNION ALL
#   SELECT
#     'df_ff' AS source_dataset,
#     "unique_id",
#     "matching_id",
#     "owner_fullname",
#     "owner_birth_date",
#     "owner_postal_code",
#     "owner_address",
#     "owner_firstname",
#     "owner_lastname",
#     RAND() AS __splink_salt
#   FROM df_ff
# ), __splink__df_tf_owner_fullname AS (
#   SELECT
#     "owner_fullname",
#     CAST(COUNT(*) AS DOUBLE) / NULLIF((
#       SELECT
#         COUNT("owner_fullname") AS total
#       FROM __splink__df_concat
#     ), 0) AS "tf_owner_fullname"
#   FROM __splink__df_concat
#   WHERE
#     NOT "owner_fullname" IS NULL
#   GROUP BY
#     "owner_fullname"
# ), __splink__df_tf_owner_lastname AS (
#   SELECT
#     "owner_lastname",
#     CAST(COUNT(*) AS DOUBLE) / NULLIF((
#       SELECT
#         COUNT("owner_lastname") AS total
#       FROM __splink__df_concat
#     ), 0) AS "tf_owner_lastname"
#   FROM __splink__df_concat
#   WHERE
#     NOT "owner_lastname" IS NULL
#   GROUP BY
#     "owner_lastname"
# ), __splink__df_tf_owner_firstname AS (
#   SELECT
#     "owner_firstname",
#     CAST(COUNT(*) AS DOUBLE) / NULLIF((
#       SELECT
#         COUNT("owner_firstname") AS total
#       FROM __splink__df_concat
#     ), 0) AS "tf_owner_firstname"
#   FROM __splink__df_concat
#   WHERE
#     NOT "owner_firstname" IS NULL
#   GROUP BY
#     "owner_firstname"
# )
# SELECT
#   __splink__df_concat.*,
#   __splink__df_tf_owner_fullname."tf_owner_fullname",
#   __splink__df_tf_owner_lastname."tf_owner_lastname",
#   __splink__df_tf_owner_firstname."tf_owner_firstname"
# FROM __splink__df_concat
# LEFT JOIN __splink__df_tf_owner_fullname
#   ON __splink__df_concat."owner_fullname" = __splink__df_tf_owner_fullname."owner_fullname"
# LEFT JOIN __splink__df_tf_owner_lastname
#   ON __splink__df_concat."owner_lastname" = __splink__df_tf_owner_lastname."owner_lastname"
# LEFT JOIN __splink__df_tf_owner_firstname
#   ON __splink__df_concat."owner_firstname" = __splink__df_tf_owner_firstname."owner_firstname"
#
# Error was: Conversion Error: Could not convert string '29PBF3HD' to INT128
# LINE 13:             "unique_id", "matching_id", "owner_fullname", "owner_birth_date", "owner_postal_code", "owner_address", "owner_firstname", "owner_lastname"
#             , random() as __splink_salt
#             from df_ff
#             ),
#
# __splink__df_tf_owner_fullname as (
#     select
#     "owner_fullname", cast(count(*) as float8) / (select
#         count("owner_fullname") as total from __splink__df_concat)
#             as "tf_owner_fullname"
#     from __splink__df_concat
#     where "owner_fullname" is not null
#     group by "owner_fullname"
#     ),
#
# __splink__df_tf_owner_lastname as (
#     select
#     "owner_lastname", cast(count(*) as float8) / (select
#         count("owner_lastname") as total from __splink__df_concat)
#             as "tf_owner_lastname"
#     from __splink__df_concat
#     where "owner_lastname" is not null
#     group by "owner_lastname"
#     ),
#
# __splink__df_tf_owner_firstname as (
#     select
#     "owner_firstname", cast(count(*) as float8) / (select
#         count("owner_firstname") as total from __splink__df_concat)
#             as "tf_owner_firstname"
#     from __splink__df_concat
#     where "owner_firstname" is not null
#     group by "owner_firstname"
#     )
#
#     select __splink__df_concat.*, __splink__df_tf_owner_fullname."tf_owner_fullname", __splink__df_tf_owner_lastname."tf_owner_lastname", __splink__df_tf_owner_firstname."tf_owner_firstname"
#     from __splink__df_concat
#     left join __splink__df_tf_owner_fullname on __splink__df_concat."owner_fullname" = __splink__df_tf_owner_fullname."owner_fullname" left join __splink__df_tf_owner_lastname on __splink__df_concat."owner_lastname" = __splink__df_tf_owner_lastname."owner_lastname" left join __splink__df_tf_owner_firstname on __splink__df_concat."owner_firstname" = __splink__df_tf_owner_firstname."owner_firstname"
#     ...
#                      ^

# %%
from splink.exploratory import similarity_analysis as sa

# %%
df

# %%
df_ff_owners
# Out:
#                                            id ff_owner_idpersonne  \
# 0        9275e4bc-681f-417d-89cb-2071a1268d10            13MDJGCJ
# 1        05fbd43b-c4bb-4f16-84fb-31139aed364d            13PBL2G4
# 2        bfb1999c-caf6-4b18-a5fe-e9062d80d9df            13PBLR69
# 3        db6c0a00-1e32-4ad7-aca8-85da53ba27c1            13MCT6LX
# 4        9dd6da3d-3030-454e-88b9-7a1fcec9a2fb            13MD2B3D
# ...                                       ...                 ...
# 2284657  1c40484c-02f4-4c5c-a5f5-5195d40fb361            97MBC632
# 2284658  6a7928a9-5fd8-4d73-a627-cd75c169e665            97MBDFWX
# 2284659  d22a08e9-181b-4520-a2f1-abf83752b88e            97MBMJBK
# 2284660  ee6d5701-7c89-43a8-b313-5fd9c838a2de            97MBDFWX
# 2284661  a66f2e44-e221-4bde-b36e-f71fa5223e33            97MBDFWX
#
#                             local_ids  \
# 0        [130420013315, 130420013315]
# 1        [130430379792, 130430379792]
# 2        [130440035941, 130440035941]
# 3        [131000247769, 131000247769]
# 4        [130530408463, 130530408463]
# ...                               ...
# 2284657  [976110028925, 976110028925]
# 2284658  [976160015705, 976160015705]
# 2284659  [974230326217, 974230326217]
# 2284660  [976160015705, 976160015705]
# 2284661  [976160015705, 976160015705]
#
#                                                full_name  \
# 0                                       TONNA MARIE-ANGE
# 1                                   MME BONNABEL MONIQUE
# 2        DE CHAMPEAUX DE LA BOULAYE ERIC ALBERT JAUFFRET
# 3                        CHOTEL THIBAULT CONSTANTIN REMY
# 4                  M LECAILLON BAPTISTIN CLOVIS AUGUSTIN
# ...                                                  ...
# 2284657                                M HAMADA TARMIDHI
# 2284658                                    ABDOU SOURAYA
# 2284659                        POONOOSAWMY GEORGES-MARIE
# 2284660                          MME ABDOU MOINAMAOULIDA
# 2284661                                      ABDOU RAIDA
#
#                        birth_date postal_code postal_code_1  \
# 0       1963-09-12 01:00:00+01:00
# 1       1953-01-15 01:00:00+01:00
# 2       1969-01-30 01:00:00+01:00
# 3       1996-07-16 02:00:00+02:00
# 4       1994-03-29 02:00:00+02:00
# ...                           ...         ...           ...
# 2284657 1977-10-06 01:00:00+01:00
# 2284658 1985-05-10 02:00:00+02:00
# 2284659 1969-10-08 01:00:00+01:00
# 2284660 1989-10-07 01:00:00+01:00
# 2284661 1996-07-04 02:00:00+02:00
#
#         ipo.address_dgfip[0]                    ff_owner_fullname  \
# 0                       None                TONNA/CATHERINE AGNES
# 1                       None                               CLEMAR
# 2                       None             SCEA DOMAINE DE L'ENCLOS
# 3                       None      CHOTEL/THIBAULT CONSTANTIN REMY
# 4                       None  LECAILLON/BAPTISTIN CLOVIS AUGUSTIN
# ...                      ...                                  ...
# 2284657                 None                      HAMADA/TARMIDHI
# 2284658                 None                        ABDOU/SOURAYA
# 2284659                 None           POONOOSAWMY/JEROME OLIVIER
# 2284660                 None                        ABDOU/SOURAYA
# 2284661                 None                        ABDOU/SOURAYA
#
#         ff_owner_birth_date         ff_owner_firstname ff_owner_lastname  \
# 0                1966-03-20                  CATHERINE           BAIGNOL
# 1                       NaT                       None              None
# 2                       NaT                       None              None
# 3                1996-07-16                   THIBAULT            CHOTEL
# 4                1994-03-29  BAPTISTIN CLOVIS AUGUSTIN         LECAILLON
# ...                     ...                        ...               ...
# 2284657          1977-10-06                   TARMIDHI            HAMADA
# 2284658          1985-05-10                    SOURAYA             ABDOU
# 2284659          1981-07-05             JEROME OLIVIER       POONOOSAWMY
# 2284660          1985-05-10                    SOURAYA             ABDOU
# 2284661          1985-05-10                    SOURAYA             ABDOU
#
#         ff_owner_postal_code owner_address  \
# 0                      83330          None
# 1                      13410          None
# 2                      13450          None
# 3                      12800          None
# 4                      13370          None
# ...                      ...           ...
# 2284657                97600          None
# 2284658                97640          None
# 2284659                97400          None
# 2284660                97640          None
# 2284661                97640          None
#
#                                   matching_id
# 0        2b2c0ad0-171d-4b54-83ba-a93da85c7045
# 1        8efb232c-fc9d-4f19-8861-94196b5496a8
# 2        39b28dd7-02a1-4b79-bf0a-a556f09a535e
# 3        dabbc494-9695-4ccc-8a2f-3d1e99f754f2
# 4        cf204e68-9db1-4c1b-82dd-ce9bc25526f7
# ...                                       ...
# 2284657  7fd46ae2-e18d-4beb-8391-f71073ede725
# 2284658  02fe6513-2d56-4726-8b3e-6783702f86f5
# 2284659  0eb396d2-0c9b-4e77-8a08-aad44f3b06fe
# 2284660  e6e29ca3-05a6-41da-9c3d-6bac96c3a26f
# 2284661  88a9082e-a7d5-4336-8b54-61aea68bff7b
#
# [2284662 rows x 15 columns]

# %%
from rapidfuzz import fuzz
from tqdm.auto import tqdm


def calculate_similarity(row):
    scores = {
        'full_name': fuzz.ratio(row['full_name'], row['ff_owner_fullname']),
        'full_name_first_name': 50 if row["ff_owner_firstname"] in row["full_name"] else 0,
        'full_name_last_name': 50 if row["ff_owner_lastname"] in row["full_name"] else 0,
        'birth_date': 100 if row['birth_date'] == row['ff_owner_birth_date'] else 0,
        'postal_code': fuzz.ratio(row['postal_code'], row['ff_owner_postal_code']),
        'address': fuzz.ratio(row['ipo.address_dgfip[0]'], row['owner_address']),
    }
    
    weights = {
        'full_name': 0.7,
        'birth_date': 0.9,
        'full_name_first_name': 0.2,
        'full_name_last_name': 0.2,
        'postal_code': 0.7,
        'address': 0.8,
    }
    
    global_score = sum(scores[k] * weights[k] for k in scores) / sum(weights.values())
    return global_score


# Ajouter une colonne avec le score de similarité
df_ff_owners['similarity_score'] = df_ff_owners.apply(calculate_similarity, axis=1)

# %%
df_ff_owners.columns
# Out:
# Index(['id', 'ff_owner_idpersonne', 'local_ids', 'full_name', 'birth_date',
#        'postal_code', 'postal_code_1', 'ipo.address_dgfip[0]',
#        'ff_owner_fullname', 'ff_owner_birth_date', 'ff_owner_firstname',
#        'ff_owner_lastname', 'ff_owner_postal_code', 'owner_address'],
#       dtype='object')
