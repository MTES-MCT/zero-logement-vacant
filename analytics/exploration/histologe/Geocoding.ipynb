# %%
import pandas as pd

# %%
histo_path = "/Users/raphaelcourivaud/Downloads/5000-signalement.csv"

df_histo = pd.read_csv(histo_path)[["ban_id_occupant", "nb_pieces_logement",
           "superficie", "prenom_proprio", "nom_proprio", 
           "code_postal_proprio", "ville_proprio", "adresse_proprio"
           ]]

# %%
# ban_id_occupant / nb_pieces_logement /
# superficie / prenom_proprio / code_postal_proprio / 
# ville_proprio / nom_proprio / adresse_proprio

# %%
df_histo
# Out:
#        ban_id_occupant  nb_pieces_logement  superficie prenom_proprio  \
# 0     06088_3235_00048                   2        42.0       Laurance
# 1     62510_2363_00005                   4        70.0            NaN
# 2     37233_1160_00197                   4        68.0            NaN
# 3     66210_0340_00024                   3        90.0     Alexandra
# 4     76675_0104_00315                   2         NaN      Christian
# ...                ...                 ...         ...            ...
# 4995  45234_0510_00092                   2        80.0       Patrice
# 4996  23093_0291_00017                   4        90.0          Henri
# 4997  73065_1370_00094                   3        70.0          Santa
# 4998  64061_0230_00096                   3        93.0            NaN
# 4999  34172_2562_00405                   1        45.0            NaN
#
#                nom_proprio  code_postal_proprio  ville_proprio  \
# 0               Philippot                   NaN            NaN
# 1          Maison et cit�                   NaN            NaN
# 2     Val Touraine Habitat                  NaN            NaN
# 3         Daniellot Leggui              66300.0          Thuir
# 4                   AVENEL              76690.0      Sierville
# ...                    ...                  ...            ...
# 4995                 Viron                  NaN            NaN
# 4996            BERTRANDIE              23600.0  Boussac-Bourg
# 4997              Mme Lupo              73000.0       Chamb�ry
# 4998     Agence Guy Hoquet              64170.0          Artix
# 4999           Acm habitat                  NaN            NaN
#
#                      adresse_proprio
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3     24 Rue du Souvenir 66300 Thuir
# 4            315a Route des Marettes
# ...                              ...
# 4995                             NaN
# 4996                    La Chassagne
# 4997             94 Rue de la feclaz
# 4998     960 Avenue De La Republique
# 4999                             NaN
#
# [5000 rows x 8 columns]
