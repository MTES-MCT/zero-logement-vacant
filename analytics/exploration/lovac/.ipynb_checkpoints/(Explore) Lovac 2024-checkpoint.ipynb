# %%
# !open ./data/

# %%
# !wc -l /Users/raphaelcourivaud/Downloads/lovac2024ff23.csv
# Out:
#  12047294 /Users/raphaelcourivaud/Downloads/lovac2024ff23.csv

# %%
import pandas as pd

# %%
"\t".join(header)
# Out:
# 'annee\tff millesime\tdir\tsip\tinvariant\tff idlocal\tff idbat\tff idpar\tff idsec\trefcad\tloc num\tloc voie\tlibvoie\tbatloc\tlibcom\tcommune\tintercommunalite\tff_idcom\tccodep\tban result score\tban result label\tban postcode\tban result id\tban latitude\tban longitude\tdistance ban ff\tff_geomloc\tff_geom\tff x\tff y\tff x 4326\tff y 4326\tnature\tff ctpdl\tff stoth\tff slocal\tff npiece p2\tff jannath\tff dnbbai\tff dnbdou\tff dnbwc\tff dcapec2\tff ndroit\tff dcntpa\tvlcad\tvl revpro\tff dvltrt\taff\tanrefthlv\ttxtlv\tpotentiel tlv thlv\tff ccthp\tffh ccthp\tdebutvacance\tcer_h1767\tanmutation\tff jdatat\tffh jdatat\tdvf datemut\tdvf nblocmut\tdvf nblog\tdvf valeurfonc\tdvf idmutation\tdvf libnatmut\tdvf vefa\tdvf codtypbien\tdvf libtypbien\tdvf filtre\tdvf codtypprov\tdvf codtypproa\tgestre ppre\tproprietaire\tcer_gestionnaire\tcer_propriétaire\tadresse1\tadresse2\tadresse3\tadresse4\tgroupe\tff_idprocpte\tff_idprodroit_1\tff jdatnss 1\tff ddenom 1\tff_dsiren_1\tff ccogrm_1\tff catpro2txt_1\tff_catpro3_1\tff_ccodro_1\tff locprop_1\tcer_ff-adresse_1\tff_idprodroit_2\tff jdatnss 2\tff ddenom 2\tff_dsiren_2\tff ccogrm_2\tff catpro2txt_2\tff_catpro3_2\tff_ccodro_2\tff locprop_2\tcer_ff-adresse_2\tff_idprodroit_3\tff jdatnss 3\tff ddenom 3\tff_dsiren_3\tff ccogrm_3\tff catpro2txt_3\tff_catpro3_3\tff_ccodro_3\tff locprop_3\tcer_ff-adresse_3\tff_idprodroit_4\tff jdatnss 4\tff ddenom 4\tff_dsiren_4\tff ccogrm_4\tff catpro2txt_4\tff_catpro3_4\tff_ccodro_4\tff locprop_4\tcer_adresse_4\tff_idprodroit_5\tff jdatnss 5\tff ddenom 5\tff_dsiren_5\tff ccogrm_5\tff catpro2txt_5\tff_catpro3_5\tff_ccodro_5\tff locprop_5\tcer_adresse_5\tff_idprodroit_6\tff jdatnss 6\tff ddenom 6\tff_dsiren_6\tff ccogrm_6\tff catpro2txt_6\tff_catpro3_6\tff_ccodro_6\tff locprop_6\tcer_adresse_6'

# %%
df_ff = pd.read_csv("/Users/raphaelcourivaud/Downloads/extff2023.csv", delimiter=";", nrows=1000)

# %%
df_ff.columns
# Out:
# Index(['ff_idlocal', 'ff_ccodep', 'ff_idcom', 'ff_millesime', 'ff_idsec',
#        'ff_idbat', 'ff_idpar', 'ff_dcntpa', 'ff_ccoriv', 'ff_dnvoiri',
#        'ff_dindic', 'ff_dvoilib', 'ff_dteloc', 'ff_ctpdl', 'ff_stoth',
#        'ff_slocal', 'ff_npiece_p2', 'ff_jannath', 'ff_jdatat', 'ff_ccthp',
#        'ff_ndroit', 'ff_rppo_rs', 'ff_dnbbai', 'ff_dnbdou', 'ff_dnbwc',
#        'ff_dcapec2', 'ff_jdatnss', 'ff_ddenom', 'ff_ccogrm', 'ff_locprop',
#        'ff_catpro2txt', 'ff_catpro2', 'ff_catpro3', 'ff_geomloc', 'ffh_ccthp',
#        'ffh_jdatat'],
#       dtype='object')

# %%
df_ff.head().to_csv("./data/export_extff_25062024.csv")

# %%
df = pd.read_csv("/Users/raphaelcourivaud/Downloads/lovac2024ff23 (1).csv", delimiter=";", nrows=1000000)
# Out:
# /var/folders/_v/10w6h3595jb25htv66pv5fq80000gn/T/ipykernel_30279/1106183909.py:1: DtypeWarning: Columns (11,49,50,56,70,72,92,102,112,122,129,130,131,132,134,135,136,138) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/Users/raphaelcourivaud/Downloads/lovac2024ff23 (1).csv", delimiter=";", nrows=1000000)

# %%
df.head().to_csv("./data/export_lovac_25062024.csv")

# %%
df.filter(regex="catpro3")
# Out:
#        ff_catpro3_1 ff_catpro3_2 ff_catpro3_3 ff_catpro3_4 ff_catpro3_5  \
# 0               X1a          X1a          NaN          NaN          NaN
# 1               X1a          X1a          NaN          NaN          NaN
# 2               X1a          X1a          NaN          NaN          NaN
# 3               X1a          X1a          X1a          X1a          X1a
# 4               X1a          X1a          NaN          NaN          NaN
# ...             ...          ...          ...          ...          ...
# 999995          X1a          NaN          NaN          NaN          NaN
# 999996          X1a          X1a          X1a          NaN          NaN
# 999997          X1a          NaN          NaN          NaN          NaN
# 999998          X1a          X1a          X1a          NaN          NaN
# 999999          P5a          NaN          NaN          NaN          NaN
#
#        ff_catpro3_6
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 999995          NaN
# 999996          NaN
# 999997          NaN
# 999998          NaN
# 999999          NaN
#
# [1000000 rows x 6 columns]

# %%
        CASE
            WHEN TRIM(groupe::TEXT) = '' THEN 'Particulier'
            WHEN NOT(owner_fullname LIKE '%' || SPLIT_PART(TRIM(ff_ddenom_1), '/', 1) || '%') AND NOT(owner_fullname LIKE '%' || SPLIT_PART(SPLIT_PART(TRIM(ff_ddenom_1), '/', 2), ' ', 1) || '%') THEN 'Autre'
            WHEN ff_catpro2txt = 'INVESTISSEUR PROFESSIONNEL' THEN 'Investisseur'
            WHEN ff_catpro2txt = 'SOCIETE CIVILE A VOCATION IMMOBILIERE' THEN 'SCI'
            ELSE ff_catpro2txt
        END AS owner_kind_detail,
        CASE
            WHEN TRIM(groupe::TEXT) = '' THEN 'Particulier'
            ELSE 'Autre'
        END AS owner_kind
# Out:
#   Cell In[95], line 1
#     ```
#     ^
# SyntaxError: invalid syntax

# %%
df["groupe"].value_counts(normalize=True, dropna=False) * 100
# Out:
# groupe
#      62.3869
# 0    19.3613
# 5    13.1181
# 4     2.4390
# 7     0.9125
# 9     0.5294
# 1     0.5045
# 6     0.4603
# 3     0.2079
# 2     0.0725
# 8     0.0076
# Name: proportion, dtype: float64

# %%
df["ff_catpro2txt_1"].value_counts(normalize=True, dropna=False) * 100
# Out:
# ff_catpro2txt_1
# PERSONNE PHYSIQUE                                         59.6479
# ORGANISME DE LOGEMENT SOCIAL                              14.3775
# SOCIETE CIVILE A VOCATION IMMOBILIERE                     12.0265
# NaN                                                        3.8476
# COMMUNE                                                    2.3091
# INVESTISSEUR PROFESSIONNEL                                 2.1479
# PERSONNE MORALE AUTRE                                      1.2569
# PROPRIETE DIVISEE EN LOT                                   1.1947
# PROMOTEUR                                                  0.5797
# ETAT                                                       0.4923
# STRUCTURE AGRICOLE                                         0.2543
# STRUCTURE SOCIALE                                          0.2316
# ETABLISSEMENT DE SANTE                                     0.2158
# STRUCTURE INTERCOMMUNALE                                   0.2006
# DEPARTEMENT                                                0.1887
# ACTIVITE DE TOURISME                                       0.1558
# ETABLISSEMENT PUBLIC FONCIER                               0.1166
# ACTIVITE INDUSTRIELLE                                      0.1149
# STRUCTURE LIEE AUX CULTES                                  0.1140
# ACTIVITE COMMERCIALE                                       0.0817
# RESEAU ELECTRIQUE OU GAZ                                   0.0799
# REGION                                                     0.0696
# RESEAU FERRE                                               0.0629
# SEM OU SPLA                                                0.0587
# CHAMBRE CONSULAIRE                                         0.0266
# STRUCTURE FORESTIERE                                       0.0259
# STRUCTURE FLUVIALE OU MARITIME                             0.0257
# STRUCTURE SPORTIVE                                         0.0219
# STRUCTURE DU FONCIER ENVIRONNEMENTAL                       0.0127
# ETABLISSEMENT D ENSEIGNEMENT DU PRIMAIRE ET SECONDAIRE     0.0107
# PERSONNE MORALE PUBLIQUE AUTRE                             0.0103
# ACTIVITE EXTRACTIVE                                        0.0094
# STRUCTURE LIEE À LA CULTURE                                0.0082
# ETABLISSEMENT PUBLIC D ETUDE OU DE RECHERCHE               0.0047
# CONCESSIONNAIRE AUTOROUTIER                                0.0045
# ASSOCIATION FONCIERE DE REMEMBREMENT                       0.0043
# RESEAU EAU OU ASSAINISSEMENT                               0.0029
# SAFER                                                      0.0023
# AMENAGEUR                                                  0.0016
# PROPRIETAIRE DE RESEAU AUTRE                               0.0011
# UNIVERSITE ET ENSEIGNEMENT SUPERIEUR                       0.0011
# COLLECTIVITE TERRITORIALE AUTRE                            0.0004
# STRUCTURE AERIENNE                                         0.0003
# RESEAU DE TELECOMMUNICATION                                0.0002
# Name: proportion, dtype: float64

# %%
df
# Out:
#      annee  ff_millesime  dir  sip     invariant   ff_idlocal  \
# 0     2024        2023.0   10  450  I0010000001Y  10010000001
# 1     2024        2023.0   10  450  I0010000089L  10010000089
# 2     2024        2023.0   10  450  I0010000115N  10010000115
# 3     2024        2023.0   10  450  I0010000124L  10010000124
# 4     2024        2023.0   10  450  I0010000220T  10010000220
# ..     ...           ...  ...  ...           ...          ...
# 995   2024        2023.0   10  751  I0040123962V  10040123962
# 996   2024        2023.0   10  751  I0040124014D  10040124014
# 997   2024        2023.0   10  751  I0040124015Z  10040124015
# 998   2024        2023.0   10  751  I0040124043N  10040124043
# 999   2024        2023.0   10  751  I0040124070G  10040124070
#
#             ff_idbat        ff_idpar    ff_idsec  refcad  ... ff_idprodroit_6  \
# 0    010010000A0003A  010010000A0003  010010000A   A0003  ...             NaN
# 1    01001000ZC0081A  01001000ZC0081  01001000ZC  ZC0081  ...             NaN
# 2    01001000ZE0075A  01001000ZE0075  01001000ZE  ZE0075  ...             NaN
# 3    01001000ZH0037A  01001000ZH0037  01001000ZH  ZH0037  ...             NaN
# 4    01001000ZM0060A  01001000ZM0060  01001000ZM  ZM0060  ...             NaN
# ..               ...             ...         ...     ...  ...             ...
# 995  01004000AO0892A  01004000AO0892  01004000AO  AO0892  ...             NaN
# 996  01004000AL0150A  01004000AL0150  01004000AL  AL0150  ...             NaN
# 997  01004000AL0150A  01004000AL0150  01004000AL  AL0150  ...             NaN
# 998  01004000BS0140C  01004000BS0140  01004000BS  BS0140  ...             NaN
# 999  01004000BT0265A  01004000BT0265  01004000BT  BT0265  ...             NaN
#
#     ff_jdatnss_6 ff_ddenom_6 ff_dsiren_6 ff_ccogrm_6  ff_catpro2txt_6  \
# 0            NaN         NaN         NaN         NaN              NaN
# 1            NaN         NaN         NaN         NaN              NaN
# 2            NaN         NaN         NaN         NaN              NaN
# 3            NaN         NaN         NaN         NaN              NaN
# 4            NaN         NaN         NaN         NaN              NaN
# ..           ...         ...         ...         ...              ...
# 995          NaN         NaN         NaN         NaN              NaN
# 996          NaN         NaN         NaN         NaN              NaN
# 997          NaN         NaN         NaN         NaN              NaN
# 998          NaN         NaN         NaN         NaN              NaN
# 999          NaN         NaN         NaN         NaN              NaN
#
#     ff_catpro3_6  ff_ccodro_6  ff_locprop_6  cer_ff_adresse_6
# 0            NaN          NaN           NaN               NaN
# 1            NaN          NaN           NaN               NaN
# 2            NaN          NaN           NaN               NaN
# 3            NaN          NaN           NaN               NaN
# 4            NaN          NaN           NaN               NaN
# ..           ...          ...           ...               ...
# 995          NaN          NaN           NaN               NaN
# 996          NaN          NaN           NaN               NaN
# 997          NaN          NaN           NaN               NaN
# 998          NaN          NaN           NaN               NaN
# 999          NaN          NaN           NaN               NaN
#
# [1000 rows x 139 columns]

# %%
df[85].unique()
# Out:
# array(['PERSONNE PHYSIQUE', 'ORGANISME DE LOGEMENT SOCIAL',
#        'SOCIETE CIVILE A VOCATION IMMOBILIERE', '\\N',
#        'PERSONNE MORALE AUTRE', 'ETAT',
#        'ETABLISSEMENT D ENSEIGNEMENT DU PRIMAIRE ET SECONDAIRE',
#        'STRUCTURE SOCIALE', 'PROPRIETE DIVISEE EN LOT', 'DEPARTEMENT',
#        'COMMUNE', 'INVESTISSEUR PROFESSIONNEL', 'RESEAU FERRE',
#        'PROMOTEUR', 'STRUCTURE INTERCOMMUNALE',
#        'ETABLISSEMENT PUBLIC FONCIER', 'REGION',
#        'STRUCTURE LIEE AUX CULTES', 'ACTIVITE INDUSTRIELLE',
#        'ACTIVITE COMMERCIALE', 'STRUCTURE AERIENNE', 'STRUCTURE AGRICOLE',
#        'ACTIVITE DE TOURISME', 'SAFER', 'ETABLISSEMENT DE SANTE',
#        'STRUCTURE FLUVIALE OU MARITIME', 'RESEAU ELECTRIQUE OU GAZ',
#        'CHAMBRE CONSULAIRE', 'STRUCTURE LIEE À LA CULTURE',
#        'UNIVERSITE ET ENSEIGNEMENT SUPERIEUR', 'SEM OU SPLA',
#        'STRUCTURE FORESTIERE', 'STRUCTURE DU FONCIER ENVIRONNEMENTAL',
#        'STRUCTURE SPORTIVE', 'RESEAU EAU OU ASSAINISSEMENT',
#        'PERSONNE MORALE PUBLIQUE AUTRE', 'ACTIVITE EXTRACTIVE',
#        'CONCESSIONNAIRE AUTOROUTIER', 'AMENAGEUR',
#        'PROPRIETAIRE DE RESEAU AUTRE', 'COLLECTIVITE TERRITORIALE AUTRE',
#        'ASSOCIATION FONCIERE DE REMEMBREMENT',
#        'ETABLISSEMENT PUBLIC D ETUDE OU DE RECHERCHE',
#        'RESEAU DE TELECOMMUNICATION'], dtype=object)

# %%
df[df.columns[-10:]]
# Out:
#              130         131                  132 133 134                135  \
# 0             \N          \N                   \N  \N  \N                 \N
# 1             \N          \N                   \N  \N  \N                 \N
# 2             \N          \N                   \N  \N  \N                 \N
# 3             \N          \N                   \N  \N  \N                 \N
# 4             \N          \N                   \N  \N  \N                 \N
# 5             \N          \N                   \N  \N  \N                 \N
# 6             \N          \N                   \N  \N  \N                 \N
# 7             \N          \N                   \N  \N  \N                 \N
# 8  01001S0007806  25/06/1948  SALUCE ANDRE ALBERT  \N  \N  PERSONNE PHYSIQUE
# 9             \N          \N                   \N  \N  \N                 \N
#
#    136 137 138                                          139
# 0   \N  \N  \N                                          NaN
# 1   \N  \N  \N                                          NaN
# 2   \N  \N  \N                                          NaN
# 3   \N  \N  \N                                          NaN
# 4   \N  \N  \N                                          NaN
# 5   \N  \N  \N                                          NaN
# 6   \N  \N  \N                                          NaN
# 7   \N  \N  \N                                          NaN
# 8  X1a   P   3  0602 AV  DU HUIT MAI 69300 CALUIRE ET CUIRE
# 9   \N  \N  \N                                          NaN
