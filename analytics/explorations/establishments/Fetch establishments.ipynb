# %%
import pandas as pd

# %%
url_communes = "https://www.insee.fr/fr/statistiques/fichier/8377162/v_commune_2025.csv"
url_departements = "https://www.insee.fr/fr/statistiques/fichier/8377162/v_departement_2025.csv"
url_regions = "https://www.insee.fr/fr/statistiques/fichier/8377162/v_region_2025.csv"

# %%
code_api_siren = [7112, 
7160,
7171,
7172,
7210,
7220,
7225,
7229,
7230,
7312,
7321,
7340,
7342,
7343,
7345,
7346,
7347,
7348,
7389,
7490,
4110,]

# %%
string_code_api_siren = "(" + ",".join([str(code) for code in code_api_siren]) + ")"

# %%
import duckdb


df = duckdb.sql(f"""
            SELECT denominationUniteLegale, activitePrincipaleUniteLegale, categorieEntreprise, sigleUniteLegale, categorieJuridiqueUniteLegale, siren
                FROM 'file:/Users/raphaelcourivaud/Downloads/base_siren.parquet'
                                WHERE categorieJuridiqueUniteLegale IN {string_code_api_siren}
            """).df()

# %%
df.to_clipboard(sep="\t", index=False)

# %%
df
# Out:
#                                  denominationUniteLegale  \
# 0                         CARREFOUR INTERNATIONAL COMMUN
# 1                    CITE DES SCIENCES ET DE L'INDUSTRIE
# 2                   EPA DU SECTEUR IV DE MARNE LA VALLEE
# 3                  OFFICE NATIONAL FORETS CENTRE GESTION
# 4                  OFFICE NATIONAL FORETS CENTRE GESTION
# ...                                                  ...
# 62850  DIRECTION INTERDEPARTEMENTALE DE LA POLICE NAT...
# 62851  DIRECTION INTERDEPARTEMENTALE DE LA POLICE NAT...
# 62852  ASSOCIATION FONCIERE D'AMENAGEMENT FONCIER AGR...
# 62853           OFFICE DE TOURISME INTERCOMMUNAL DU NORD
# 62854  ASSOCIATION FONCIERE D'AMENAGEMENT FONCIER AGR...
#
#       activitePrincipaleUniteLegale categorieEntreprise sigleUniteLegale  \
# 0                             77.01                None             None
# 1                            91.02Z                None              CSI
# ...

# %%
df_communes = pd.read_csv(url_communes)
df_departements = pd.read_csv(url_departements)
df_regions = pd.read_csv(url_regions)

df_communes.head()
df_departements.head()
df_regions.head()
# Out:
#    REG CHEFLIEU  TNCC         NCC      NCCENR     LIBELLE
# 0    1    97105     3  GUADELOUPE  Guadeloupe  Guadeloupe
# 1    2    97209     3  MARTINIQUE  Martinique  Martinique
# 2    3    97302     3      GUYANE      Guyane      Guyane
# 3    4    97411     0  LA REUNION  La Réunion  La Réunion
# 4    6    97611     0     MAYOTTE     Mayotte     Mayotte

# %%
df_departements
# Out:
#      DEP  REG CHEFLIEU  TNCC                      NCC  \
# 0     01   84    01053     5                      AIN
# 1     02   32    02408     5                    AISNE
# 2     03   84    03190     5                   ALLIER
# 3     04   93    04070     4  ALPES DE HAUTE PROVENCE
# 4     05   93    05061     4             HAUTES ALPES
# ..   ...  ...      ...   ...                      ...
# 96   971    1    97105     3               GUADELOUPE
# 97   972    2    97209     3               MARTINIQUE
# 98   973    3    97302     3                   GUYANE
# 99   974    4    97411     0               LA REUNION
# 100  976    6    97611     0                  MAYOTTE
#
#                       NCCENR                  LIBELLE
# 0                        Ain                      Ain
# 1                      Aisne                    Aisne
# 2                     Allier                   Allier
# 3    Alpes-de-Haute-Provence  Alpes-de-Haute-Provence
# ...

# %%
df_communes
# Out:
#       TYPECOM    COM   REG  DEP  CTCD  ARR  TNCC                    NCC  \
# 0         COM  01001  84.0   01   01D  012     5  ABERGEMENT CLEMENCIAT
# 1         COM  01002  84.0   01   01D  011     5    ABERGEMENT DE VAREY
# 2         COM  01004  84.0   01   01D  011     1      AMBERIEU EN BUGEY
# 3         COM  01005  84.0   01   01D  012     1    AMBERIEUX EN DOMBES
# 4         COM  01006  84.0   01   01D  011     1                AMBLEON
# ...       ...    ...   ...  ...   ...  ...   ...                    ...
# 37543     COM  97613   6.0  976  976D  NaN     0          M TSANGAMOUJI
# 37544     COM  97614   6.0  976  976D  NaN     1               OUANGANI
# 37545     COM  97615   6.0  976  976D  NaN     0               PAMANDZI
# 37546     COM  97616   6.0  976  976D  NaN     0                   SADA
# 37547     COM  97617   6.0  976  976D  NaN     0               TSINGONI
#
#                       NCCENR                  LIBELLE    CAN  COMPARENT
# ...
